# %% [markdown]
# # Filtrando solicitudes
#
# Pyratilla hizo un formulario para que los interesados en formar parte de su tripulación rellenaran y así poder evitarse más de una entrevista innecesaria.
#
# Ahora es momento de filtrar las convocatorias:
#
# - El nombre debe empezar por mayúscula. Si es un nombre compuesto, entonces todos deben empezar por mayúscula.
# - La edad debe ser mayor o igual a 16 y menor o igual a 40.
# - El hobby indicado debe tener más de 10 caracteres.
# - La casilla del sueño no puede haber sido dejada en blanco.
#
# Ayuda a Pyratilla a crear este filtro para descartar solicitudes que no cumplan estos requisitos.

# %%
novalido_edad_joven = False
novalido_edad_mayor = False

nombre = str(input("Introduce tu mombre: ")) 
while nombre.isprintable() == False:
    nombre = str(input("Introduce tu mombre: ")) 
nombre_mayuscula=nombre.title()

edad = int(input("Introduce tu edad: "))
    
if int(edad) <= 16:
    
    novalido_edad_joven = True

if int(edad) > 40:
    
    novalido_edad_mayor = True
   

hobbie = str(input("Introduce un Hobbie: ")) 

while len(hobbie) < 10:
    print("Esmerate más, almenos 10 caracteres")
    hobbie = str(input("Introduce un Hobbie: ")) 

if novalido_edad_joven == True: print("Eres demasiado joven {}, vuelve cuando seas más mayor!".format(nombre_mayuscula))

if novalido_edad_mayor == True: print("Eres demasiado mayor {}!,".format(nombre_mayuscula))
    
if novalido_edad_joven == False and novalido_edad_mayor == False:

    print ("Enhora Buena {}, eres apto para la entrevista con el capitán".format(nombre_mayuscula))
# Out:
# Introduce tu mombre: juan pedro
# Introduce tu edad: 78
# Introduce un Hobbie: mirar por la ventana de mi camarote
# Eres demasiado mayor Juan Pedro!,
