# %% [markdown]
# #**Productos financieros**
#
# ##*Creamos una clase*
# ###Definimos los atributos comunes a todos los activos financieros
# * Tipo (forex,acciones,futuros)
#
# ###Creamos un objeto por cada producto
#
# * Ticker
# * Ticks por punto
# * Precio por punto
